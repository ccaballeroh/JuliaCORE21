# %% [markdown]
# # Despacho múltiple (*multiple dispatch*)

# %% [markdown]
# En este *notebook*, exploramos el despacho múltiple (*multiple dispatch*), que es una característica clave de Julia.
#
# El despacho múltiple es hace que el *software* sea **genérico** y **rápido**.
#
# #### Comenzando con lo conocido
#
# Para entender el despacho múltiple en Julia, comencemos con lo que ya hemos visto.
#
# Podemos declarar funciones en Julia sin darle mucha información sobre los tipos de los argumentos de entrada que la función recibirá:

# %%
f(x) = x^2
# Out:
# f (generic function with 1 method)

# %% [markdown]
# y después Julia determinará por su cuenta qué tipos de argumentos de entrada tienen sentido y cuáles no:

# %%
f(10)
# Out:
# 100

# %%
f([1, 2, 3])
# Out:
# MethodError: no method matching ^(::Array{Int64,1}, ::Int64)
# Closest candidates are:
#   ^(!Matched::Float32, ::Integer) at math.jl:907
#   ^(!Matched::Irrational{:ℯ}, ::Integer) at mathconstants.jl:91
#   ^(!Matched::Irrational{:ℯ}, ::Number) at mathconstants.jl:91
#   ...
#
# Stacktrace:
#  [1] macro expansion at .\none:0 [inlined]
#  [2] literal_pow at .\none:0 [inlined]
#  [3] f(::Array{Int64,1}) at .\In[1]:1
#  [4] top-level scope at In[3]:1
#  [5] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %% [markdown]
# #### Especificando los tipos de nuestros argumentos de entrada
#
# Sin embargo, también tenemos la *opción* de decirle a Julia de forma explícita qué tipos están permitidos en nuestros argumentos de entrada.
#
# Por ejemplo, escribamos una función `foo` que solo tome cadenas como entradas.

# %%
foo(x::String, y::String) = println("¡Mis entradas x y y son ambas cadenas!")
# Out:
# foo (generic function with 1 method)

# %% [markdown]
# Aquí vemos que para poder restringir el tipo de `x` y `y` a `String`, solo debemos escribir después del nombre del argumento de entrada dos dos puntos (::) y la palabra reservada `String`.
#
# Ahora, veremos que `foo` funciona con cadenas y no funciona con otros tipos de argumentos de entrada.

# %%
foo("Hola", "Hi")
# Out:
# ¡Mis entradas x y y son ambas cadenas!

# %%
foo(3, 4)
# Out:
# MethodError: no method matching foo(::Int64, ::Int64)
#
# Stacktrace:
#  [1] top-level scope at In[6]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %% [markdown]
# Para hacer que `foo` trabaje en entradas enteras (de tipo `Int`), solo ponemos `::Int` en nuestros argumentos de entrada cuando declaramos `foo`.

# %%
foo(x::Int, y::Int) = println("Mis entradas x y y son ambas enteras")
# Out:
# foo (generic function with 2 methods)

# %%
foo(3, 4)
# Out:
# Mis entradas x y y son ambas enteras

# %% [markdown]
# Ahora, `foo` funciona con enteros. Pero mira que `foo` también aún funciona cuando `x` y `y` son cadenas.

# %%
foo("hello", "hi!")
# Out:
# ¡Mis entradas x y y son ambas cadenas!

# %% [markdown]
# Esto comienza a llegar al corazón del despacho múltiple. Cuando declaramos
#
# ```julia
# foo(x::Int, y::Int) = println("Mis entradas x y y son ambas enteras")
# ```
#
# no sobreescribimos o reemplazamos
#
# ```julia
# foo(x::String, y::String)
# ```
#
# En su lugar, solo agregamos un ***método*** adicional a la ***función genérica*** llamada `foo`.
#
# Una ***función genérica*** es el concepto abstracto asociado con una operación en particular.
#
# Por ejemplo, la función genérica `+` representa el concepto de adición.
#
# Un ***método*** es una implementación específica de una función genérica para *tipos de argumentos particulares*.
#
# Por ejemplo, `+` tiene métodos que aceptan números de punto flotante, enteros, matrices, etc.
#
# Podemos usar los `métodos` para ver cuántos métodos existen para `foo`.

# %%
methods(foo)
# Out:
# # 2 methods for generic function "foo":
# [1] foo(x::Int64, y::Int64) in Main at In[7]:1
# [2] foo(x::String, y::String) in Main at In[4]:1

# %% [markdown]
# Nota aparte: ¿cuántos métodos piensas que hay para la suma?

# %%
+(2, 3, 5)
# Out:
# 10

# %%
methods(+)
# Out:
# # 184 methods for generic function "+":
# [1] +(x::Float32, y::Float32) in Base at float.jl:400
# [2] +(a::Pkg.Resolve.VersionWeight, b::Pkg.Resolve.VersionWeight) in Pkg.Resolve at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Pkg\src\Resolve\versionweights.jl:22
# [3] +(dt::Dates.DateTime, z::Dates.Month) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:47
# [4] +(dt::Dates.DateTime, y::Dates.Year) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:23
# [5] +(x::Dates.DateTime, y::Dates.Period) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:76
# [6] +(a::Float16, b::Float16) in Base at float.jl:398
# [7] +(level::Base.CoreLogging.LogLevel, inc::Integer) in Base.CoreLogging at logging.jl:116
# [8] +(x::Dates.Date, y::Dates.Day) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:74
# [9] +(x::Dates.Date, y::Dates.Week) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:72
# [10] +(dt::Dates.Date, z::Dates.Month) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:54
# [11] +(dt::Dates.Date, y::Dates.Year) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:27
# [12] +(dt::Dates.Date, t::Dates.Time) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:19
# [13] +(t::Dates.Time, dt::Dates.Date) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:20
# [14] +(x::Dates.Time, y::Dates.TimePeriod) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:78
# [15] +(x::Bool, z::Complex{Bool}) in Base at complex.jl:286
# [16] +(x::Bool, y::Bool) in Base at bool.jl:96
# [17] +(x::Bool) in Base at bool.jl:93
# [18] +(x::Bool, y::T) where T<:AbstractFloat in Base at bool.jl:103
# [19] +(x::Bool, z::Complex) in Base at complex.jl:293
# [20] +(a::Pkg.Resolve.FieldValue, b::Pkg.Resolve.FieldValue) in Pkg.Resolve at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Pkg\src\Resolve\fieldvalues.jl:43
# [21] +(c::BigInt, x::BigFloat) in Base.MPFR at mpfr.jl:399
# [22] +(a::BigInt, b::BigInt, c::BigInt, d::BigInt, e::BigInt) in Base.GMP at gmp.jl:518
# [23] +(a::BigInt, b::BigInt, c::BigInt, d::BigInt) in Base.GMP at gmp.jl:517
# [24] +(a::BigInt, b::BigInt, c::BigInt) in Base.GMP at gmp.jl:516
# [25] +(x::BigInt, y::BigInt) in Base.GMP at gmp.jl:476
# [26] +(x::BigInt, c::Union{UInt16, UInt32, UInt8}) in Base.GMP at gmp.jl:524
# [27] +(x::BigInt, c::Union{Int16, Int32, Int8}) in Base.GMP at gmp.jl:530
# [28] +(z::Complex{Bool}, x::Bool) in Base at complex.jl:287
# [29] +(z::Complex{Bool}, x::Real) in Base at complex.jl:301
# [30] +(x::Dates.CompoundPeriod, y::Dates.CompoundPeriod) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\periods.jl:347
# [31] +(x::Dates.CompoundPeriod, y::Dates.Period) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\periods.jl:345
# [32] +(x::Dates.CompoundPeriod, y::Dates.TimeType) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\periods.jl:375
# [33] +(B::BitArray{2}, J::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\uniformscaling.jl:117
# [34] +(::Missing, ::Missing) in Base at missing.jl:114
# [35] +(::Missing) in Base at missing.jl:100
# [36] +(::Missing, ::Number) in Base at missing.jl:115
# [37] +(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat, e::BigFloat) in Base.MPFR at mpfr.jl:548
# [38] +(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat) in Base.MPFR at mpfr.jl:541
# [39] +(a::BigFloat, b::BigFloat, c::BigFloat) in Base.MPFR at mpfr.jl:535
# [40] +(x::BigFloat, c::BigInt) in Base.MPFR at mpfr.jl:394
# [41] +(x::BigFloat, y::BigFloat) in Base.MPFR at mpfr.jl:363
# [42] +(x::BigFloat, c::Union{UInt16, UInt32, UInt8}) in Base.MPFR at mpfr.jl:370
# [43] +(x::BigFloat, c::Union{Int16, Int32, Int8}) in Base.MPFR at mpfr.jl:378
# [44] +(x::BigFloat, c::Union{Float16, Float32, Float64}) in Base.MPFR at mpfr.jl:386
# [45] +(x::Float64, y::Float64) in Base at float.jl:401
# [46] +(y::AbstractFloat, x::Bool) in Base at bool.jl:106
# [47] +(x::T, y::T) where T<:Union{Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8} in Base at int.jl:86
# [48] +(c::Union{UInt16, UInt32, UInt8}, x::BigInt) in Base.GMP at gmp.jl:525
# [49] +(c::Union{Int16, Int32, Int8}, x::BigInt) in Base.GMP at gmp.jl:531
# [50] +(a::Integer, b::Integer) in Base at int.jl:918
# [51] +(x::Integer, y::Ptr) in Base at pointer.jl:161
# [52] +(z::Complex) in Base at complex.jl:273
# [53] +(z::Complex, w::Complex) in Base at complex.jl:275
# [54] +(z::Complex, x::Bool) in Base at complex.jl:294
# [55] +(x::Rational) in Base at rational.jl:266
# [56] +(x::Real, z::Complex{Bool}) in Base at complex.jl:300
# [57] +(x::Real, z::Complex) in Base at complex.jl:312
# [58] +(z::Complex, x::Real) in Base at complex.jl:313
# [59] +(x::Rational, y::Rational) in Base at rational.jl:282
# [60] +(x::Rational, y::Integer) in Base at rational.jl:287
# [61] +(y::Integer, x::Rational) in Base at rational.jl:294
# [62] +(x::Integer, y::AbstractChar) in Base at char.jl:224
# [63] +(c::Union{UInt16, UInt32, UInt8}, x::BigFloat) in Base.MPFR at mpfr.jl:375
# [64] +(c::Union{Int16, Int32, Int8}, x::BigFloat) in Base.MPFR at mpfr.jl:383
# [65] +(c::Union{Float16, Float32, Float64}, x::BigFloat) in Base.MPFR at mpfr.jl:391
# [66] +(x::AbstractIrrational, y::AbstractIrrational) in Base at irrationals.jl:156
# [67] +(x::Number) in Base at operators.jl:513
# [68] +(x::T, y::T) where T<:Number in Base at promotion.jl:384
# [69] +(x::Number, y::Number) in Base at promotion.jl:311
# [70] +(r1::OrdinalRange, r2::OrdinalRange) in Base at range.jl:1055
# [71] +(r1::LinRange{T}, r2::LinRange{T}) where T in Base at range.jl:1062
# [72] +(r1::StepRangeLen{T,R,S} where S, r2::StepRangeLen{T,R,S} where S) where {R<:Base.TwicePrecision, T} in Base at twiceprecision.jl:577
# [73] +(r1::StepRangeLen{T,S,S1} where S1, r2::StepRangeLen{T,S,S1} where S1) where {T, S} in Base at range.jl:1078
# [74] +(r1::Union{LinRange, OrdinalRange, StepRangeLen}, r2::Union{LinRange, OrdinalRange, StepRangeLen}) in Base at range.jl:1071
# [75] +(x::Ptr, y::Integer) in Base at pointer.jl:159
# [76] +(x::Base.TwicePrecision, y::Number) in Base at twiceprecision.jl:267
# [77] +(x::Number, y::Base.TwicePrecision) in Base at twiceprecision.jl:271
# [78] +(x::Base.TwicePrecision{T}, y::Base.TwicePrecision{T}) where T in Base at twiceprecision.jl:273
# [79] +(x::Base.TwicePrecision, y::Base.TwicePrecision) in Base at twiceprecision.jl:278
# [80] +(A::Array, Bs::Array...) in Base at arraymath.jl:43
# [81] +(A::BitArray, B::BitArray) in Base at bitarray.jl:1110
# [82] +(r::AbstractRange{var"#s828"} where var"#s828"<:Dates.TimeType, x::Dates.Period) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\ranges.jl:59
# [83] +(A::Array, B::SparseArrays.AbstractSparseMatrixCSC) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\sparsematrix.jl:1683
# [84] +(x::StridedArray{var"#s828", N} where N where var"#s828"<:Union{Dates.CompoundPeriod, Dates.Period}) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\deprecated.jl:55
# [85] +(x::StridedArray{var"#s828", N} where N where var"#s828"<:Union{Dates.CompoundPeriod, Dates.Period}, y::Dates.TimeType) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\deprecated.jl:10
# [86] +(X::StridedArray{var"#s828", N} where N where var"#s828"<:Union{Dates.CompoundPeriod, Dates.Period}, Y::StridedArray{var"#s827", N} where N where var"#s827"<:Union{Dates.CompoundPeriod, Dates.Period}) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\deprecated.jl:62
# [87] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.SymTridiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\tridiag.jl:205
# [88] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.Tridiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\tridiag.jl:732
# [89] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\triangular.jl:659
# [90] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\triangular.jl:660
# [91] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UnitUpperTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\triangular.jl:661
# [92] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.UnitLowerTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\triangular.jl:662
# [93] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\triangular.jl:663
# [94] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\triangular.jl:664
# [95] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.UnitUpperTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\triangular.jl:665
# [96] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.UnitLowerTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\triangular.jl:666
# [97] +(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\triangular.jl:667
# [98] +(A::LinearAlgebra.Hermitian, B::LinearAlgebra.Hermitian) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\symmetric.jl:466
# [99] +(A::LinearAlgebra.Symmetric, B::LinearAlgebra.Symmetric) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\symmetric.jl:466
# [100] +(A::LinearAlgebra.Hermitian{var"#s816",var"#s815"} where var"#s815"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s816", B::LinearAlgebra.Symmetric{var"#s814",var"#s813"} where var"#s813"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s814"<:Real) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:24
# [101] +(A::LinearAlgebra.Hermitian, B::LinearAlgebra.Symmetric{var"#s828",S} where S<:(AbstractArray{var"#s8281",2} where var"#s8281"<:var"#s828") where var"#s828"<:Real) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\symmetric.jl:480
# [102] +(A::LinearAlgebra.Symmetric{var"#s820",var"#s819"} where var"#s819"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s820"<:Real, B::LinearAlgebra.Hermitian{var"#s818",var"#s817"} where var"#s817"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s818") in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:23
# [103] +(A::LinearAlgebra.Symmetric{var"#s827",S} where S<:(AbstractArray{var"#s828",2} where var"#s828"<:var"#s827") where var"#s827"<:Real, B::LinearAlgebra.Hermitian) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\symmetric.jl:481
# [104] +(Da::LinearAlgebra.Diagonal, Db::LinearAlgebra.Diagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\diagonal.jl:156
# [105] +(D::LinearAlgebra.Diagonal, S::LinearAlgebra.Symmetric) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\diagonal.jl:160
# [106] +(S::LinearAlgebra.Symmetric, D::LinearAlgebra.Diagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\diagonal.jl:163
# [107] +(D::LinearAlgebra.Diagonal{var"#s828",V} where V<:AbstractArray{var"#s828",1} where var"#s828"<:Real, H::LinearAlgebra.Hermitian) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\diagonal.jl:166
# [108] +(H::LinearAlgebra.Hermitian, D::LinearAlgebra.Diagonal{var"#s828",V} where V<:AbstractArray{var"#s828",1} where var"#s828"<:Real) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\diagonal.jl:169
# [109] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\bidiag.jl:347
# [110] +(UL::LinearAlgebra.UnitUpperTriangular, J::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\uniformscaling.jl:147
# [111] +(UL::LinearAlgebra.UnitLowerTriangular, J::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\uniformscaling.jl:147
# [112] +(A::LinearAlgebra.Hermitian, J::LinearAlgebra.UniformScaling{var"#s828"} where var"#s828"<:Complex) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\uniformscaling.jl:161
# [113] +(H::LinearAlgebra.UpperHessenberg, J::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\hessenberg.jl:106
# [114] +(A::LinearAlgebra.Tridiagonal{var"#s828",V} where V<:AbstractArray{var"#s828",1} where var"#s828"<:Number, B::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:226
# [115] +(A::LinearAlgebra.SymTridiagonal{var"#s828",V} where V<:AbstractArray{var"#s828",1} where var"#s828"<:Number, B::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:231
# [116] +(A::LinearAlgebra.Bidiagonal{var"#s828",V} where V<:AbstractArray{var"#s828",1} where var"#s828"<:Number, B::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:236
# [117] +(A::LinearAlgebra.Diagonal{var"#s828",V} where V<:AbstractArray{var"#s828",1} where var"#s828"<:Number, B::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:241
# [118] +(A::SparseArrays.AbstractSparseMatrixCSC, J::LinearAlgebra.UniformScaling) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\sparsematrix.jl:3641
# [119] +(A::AbstractArray{T,2} where T, J::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\uniformscaling.jl:180
# [120] +(A::LinearAlgebra.UpperHessenberg, B::LinearAlgebra.UpperHessenberg) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\hessenberg.jl:101
# [121] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:86
# [122] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:94
# [123] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:86
# [124] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UnitUpperTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:94
# [125] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:86
# [126] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:94
# [127] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:86
# [128] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UnitLowerTriangular) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:94
# [129] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Diagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:115
# [130] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:125
# [131] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.SymTridiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:135
# [132] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Diagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:145
# [133] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.SymTridiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:157
# [134] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Tridiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:159
# [135] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.Tridiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:163
# [136] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.Diagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:173
# [137] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Tridiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:183
# [138] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:193
# [139] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.SymTridiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:203
# [140] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Bidiagonal) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:213
# [141] +(A::SparseArrays.AbstractSparseMatrixCSC, B::SparseArrays.AbstractSparseMatrixCSC) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\sparsematrix.jl:1679
# [142] +(A::SparseArrays.AbstractSparseMatrixCSC, B::Array) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\sparsematrix.jl:1682
# [143] +(x::SparseArrays.AbstractSparseArray{Tv,Ti,1} where Ti where Tv, y::SparseArrays.AbstractSparseArray{Tv,Ti,1} where Ti where Tv) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\sparsevector.jl:1302
# [144] +(A::SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv, B::LinearAlgebra.Hermitian{var"#s828",var"#s827"} where var"#s827"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s828") in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:12
# [145] +(A::LinearAlgebra.Hermitian{var"#s826",var"#s825"} where var"#s825"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s826", B::SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:13
# [146] +(A::SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv, B::LinearAlgebra.Hermitian) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:15
# [147] +(A::LinearAlgebra.Hermitian, B::SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:16
# [148] +(A::SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv, B::LinearAlgebra.Symmetric{var"#s828",var"#s827"} where var"#s827"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s828") in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:12
# [149] +(A::LinearAlgebra.Symmetric{var"#s826",var"#s825"} where var"#s825"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s826", B::SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:13
# [150] +(A::SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv, B::LinearAlgebra.Symmetric) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:15
# [151] +(A::LinearAlgebra.Symmetric, B::SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:16
# [152] +(A::LinearAlgebra.Symmetric{var"#s828",var"#s827"} where var"#s827"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s828", B::LinearAlgebra.Hermitian{var"#s826",var"#s825"} where var"#s825"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s826") in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:21
# [153] +(A::LinearAlgebra.Hermitian{var"#s824",var"#s823"} where var"#s823"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s824", B::LinearAlgebra.Symmetric{var"#s822",var"#s821"} where var"#s821"<:(SparseArrays.AbstractSparseArray{Tv,Ti,2} where Ti where Tv) where var"#s822") in SparseArrays at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\SparseArrays\src\linalg.jl:22
# [154] +(x::AbstractArray{var"#s91",N} where N where var"#s91"<:Number) in Base at abstractarraymath.jl:97
# [155] +(A::AbstractArray, B::AbstractArray) in Base at arraymath.jl:37
# [156] +(x::T, y::Integer) where T<:AbstractChar in Base at char.jl:223
# [157] +(index1::CartesianIndex{N}, index2::CartesianIndex{N}) where N in Base.IteratorsMD at multidimensional.jl:113
# [158] +(::Number, ::Missing) in Base at missing.jl:116
# [159] +(x::P, y::P) where P<:Dates.Period in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\periods.jl:78
# [160] +(x::Dates.Period, y::Dates.Period) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\periods.jl:344
# [161] +(y::Dates.Period, x::Dates.CompoundPeriod) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\periods.jl:346
# [162] +(x::Union{Dates.CompoundPeriod, Dates.Period}) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\periods.jl:355
# [163] +(x::Dates.TimeType) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:8
# [164] +(a::Dates.TimeType, b::Dates.Period, c::Dates.Period) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\periods.jl:366
# [165] +(a::Dates.TimeType, b::Dates.Period, c::Dates.Period, d::Dates.Period...) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\periods.jl:367
# [166] +(x::Dates.TimeType, y::Dates.CompoundPeriod) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\periods.jl:369
# [167] +(x::Dates.Instant) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:4
# [168] +(y::Dates.Period, x::Dates.TimeType) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\arithmetic.jl:80
# [169] +(x::Dates.Period, r::AbstractRange{var"#s828"} where var"#s828"<:Dates.TimeType) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\ranges.jl:58
# [170] +(x::AbstractArray{var"#s828",N} where N where var"#s828"<:Dates.TimeType, y::Union{Dates.CompoundPeriod, Dates.Period}) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\deprecated.jl:6
# [171] +(y::Union{Dates.CompoundPeriod, Dates.Period}, x::AbstractArray{var"#s828",N} where N where var"#s828"<:Dates.TimeType) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\deprecated.jl:14
# [172] +(y::Dates.TimeType, x::StridedArray{var"#s828", N} where N where var"#s828"<:Union{Dates.CompoundPeriod, Dates.Period}) in Dates at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\Dates\src\deprecated.jl:18
# [173] +(J::LinearAlgebra.UniformScaling, x::Number) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\uniformscaling.jl:111
# [174] +(x::Number, J::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\uniformscaling.jl:112
# [175] +(J1::LinearAlgebra.UniformScaling, J2::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\uniformscaling.jl:116
# [176] +(J::LinearAlgebra.UniformScaling, B::BitArray{2}) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\uniformscaling.jl:118
# [177] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.Tridiagonal{var"#s828",V} where V<:AbstractArray{var"#s828",1} where var"#s828"<:Number) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:245
# [178] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.SymTridiagonal{var"#s828",V} where V<:AbstractArray{var"#s828",1} where var"#s828"<:Number) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:250
# [179] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.Bidiagonal{var"#s828",V} where V<:AbstractArray{var"#s828",1} where var"#s828"<:Number) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:255
# [180] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.Diagonal{var"#s828",V} where V<:AbstractArray{var"#s828",1} where var"#s828"<:Number) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\special.jl:260
# [181] +(J::LinearAlgebra.UniformScaling, A::AbstractArray{T,2} where T) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\uniformscaling.jl:119
# [182] +(F::LinearAlgebra.Hessenberg, J::LinearAlgebra.UniformScaling) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\hessenberg.jl:559
# [183] +(J::LinearAlgebra.UniformScaling, F::LinearAlgebra.Hessenberg) in LinearAlgebra at D:\Programas\Julia 1.5.3\share\julia\stdlib\v1.5\LinearAlgebra\src\hessenberg.jl:560
# [184] +(a, b, c, xs...) in Base at operators.jl:538

# %% [markdown]
# Así que ahora podemos llamar `foo` con enteros o cadenas. Cuando llamas `foo` para un conjunto específico de argumentos, Julia inferirá los tipos de las entradas y *despachará* el método apropiado. *Esto* es el despacho múltiple.
#
# El despacho múltiple hace que nuestro código sea genérico y rápido. Nuestro código puede ser genérico y flexible porque podemos escribir código en términos de operaciones abstractas tales como la suma y la multiplicación, en lugar de en términos de implementaciones específicas. Al mismo tiempo, nuestro código corre de forma rápida porque Julia es capaz de llamar métodos eficientes para los tipos relevantes.
#
# Para ver qué métodos es el que está siendo despachado cuando llamamos una función genérica, podemos usar la macro `@which`:

# %%
@which foo(3, 4)
# Out:
# foo(x::Int64, y::Int64) in Main at In[7]:1

# %% [markdown]
# Veamos qué sucede cuando usamos `@which` con el operador de suma.

# %%
@which 3 + 3.0
# Out:
# +(x::Number, y::Number) in Base at promotion.jl:311

# %% [markdown]
# Y podemos continuar agregando otros métodos a nuestra función genérica `foo`. Agreguemos uno que tome el ***tipo abstracto*** `Number`, que incluye los subtipos tales como `Int`, `Float64` y otros objetos pudiera pensar como números:

# %%
foo(x::Number, y::Number) = println("Mis entradas x y y son ambas números")
# Out:
# foo (generic function with 3 methods)

# %% [markdown]
# Este método para `foo` funcionará en, por ejemplo, números de punto flotante:

# %%
foo(3.0, 4.0)
# Out:
# Mis entradas x y y son ambas números

# %% [markdown]
# También podemos agregar un método que tome entradas de cualquier tipo:

# %%
foo(x, y) = println("Acepto entradas de cualquier tipo")
# Out:
# foo (generic function with 4 methods)

# %% [markdown]
# Con los métodos que hemos escrito hasta ahora para `foo`, este método será llamado cuando le pasemos cosas que no son números a `foo`:

# %%
v = rand(3)
foo(v, v)
# Out:
# Acepto entradas de cualquier tipo

# %%
@which foo(v, v)
# Out:
# foo(x, y) in Main at In[21]:1

# %% [markdown]
# ### Ejercicios
#
# #### 7.1
#
# Extiende la función `foo` al agregar un método que tome únicamente un argumento de entrada que sea de tipo `Bool` y regrese "foo con un booleano"

# %%
function foo(x::Bool)::String
  return "foo con un booleano"
end
# Out:
# foo (generic function with 5 methods)

# %%
methods(foo)
# Out:
# # 5 methods for generic function "foo":
# [1] foo(x::Bool) in Main at In[24]:1
# [2] foo(x::Int64, y::Int64) in Main at In[7]:1
# [3] foo(x::String, y::String) in Main at In[4]:1
# [4] foo(x::Number, y::Number) in Main at In[19]:1
# [5] foo(x, y) in Main at In[21]:1

# %% [markdown]
# #### 7.2
#
# Verifica que el método despachado al ejecutar
# ```julia
# foo(true)
# ```
# es el que escribiste.

# %%
@which foo(true)
# Out:
# foo(x::Bool) in Main at In[24]:1

# %%
@assert foo(true) == "foo con un booleano"
